# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish1176/Deep-Learning-Project/blob/main/Processing_image_data_for_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://t3.ftcdn.net/jpg/07/17/33/40/360_F_717334058_zZu41aMmrR0CvBxI3WLbWRjrqFyLAdW1.jpg'
# Out:
# --2024-06-10 06:03:44--  https://t3.ftcdn.net/jpg/07/17/33/40/360_F_717334058_zZu41aMmrR0CvBxI3WLbWRjrqFyLAdW1.jpg
# Resolving t3.ftcdn.net (t3.ftcdn.net)... 151.101.1.167, 151.101.65.167, 151.101.129.167, ...
# Connecting to t3.ftcdn.net (t3.ftcdn.net)|151.101.1.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32611 (32K) [image/jpeg]
# Saving to: ‘360_F_717334058_zZu41aMmrR0CvBxI3WLbWRjrqFyLAdW1.jpg’
#
# 360_F_717334058_zZu 100%[===================>]  31.85K  --.-KB/s    in 0.008s
#
# 2024-06-10 06:03:44 (3.90 MB/s) - ‘360_F_717334058_zZu41aMmrR0CvBxI3WLbWRjrqFyLAdW1.jpg’ saved [32611/32611]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# **Converting image into Array**

# %%
img = mpimg.imread('/content/cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (360, 360, 3)

# %%
print(img)
# Out:
# [[[138 119 113]
#   [139 120 114]
#   [139 120 113]
#   ...
#   [ 56  55  61]
#   [ 53  52  58]
#   [ 50  49  55]]
#
#  [[139 120 114]
#   [139 120 114]
#   [140 121 114]
#   ...
#   [ 56  55  61]
#   [ 53  52  58]
#   [ 50  49  55]]
#
#  [[139 120 114]
#   [140 121 115]
#   [140 121 115]
#   ...
#   [ 57  56  62]
#   [ 53  52  58]
#   [ 50  49  55]]
#
#  ...
#
#  [[184 173 179]
#   [185 174 180]
#   [186 175 181]
#   ...
#   [ 76 105 139]
#   [ 78 104 139]
#   [ 77 103 138]]
#
#  [[181 171 179]
#   [182 172 180]
#   [183 174 179]
#   ...
#   [ 77 103 136]
#   [ 76 102 135]
#   [ 76 102 135]]
#
#  [[180 170 178]
#   [180 170 178]
#   [181 171 179]
#   ...
#   [ 75 102 132]
#   [ 75 102 132]
#   [ 75 102 132]]]

# %% [markdown]
# **Converting Array into image**

# %%
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# **Resizing the image using Pillow library**

# %%
from PIL import Image

# %%
img = Image.open('/content/cat.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('cat_image_resized.jpg')

# %%
img_res = mpimg.imread('/content/cat_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (360, 360, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (360, 360)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=360x360>

# %%
# saving the grayscale image
cv2.imwrite('cat_grayscale_image.jpg', grayscale_image)
# Out:
# True
